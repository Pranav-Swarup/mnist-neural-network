# %%
import networkx as nx
G = nx.DiGraph()
G.add_edge("A", "B")
nx.info(G)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 4
#       2 G = nx.DiGraph()
#       3 G.add_edge("A", "B")
# ----> 4 nx.info(G)
#
# File ~/psk/graphs/venv/lib/python3.12/site-packages/networkx/__init__.py:62, in __getattr__(name)
#      57 if name == "random_tree":
#      58     raise AttributeError(
#      59         "nx.random_tree was removed in version 3.4. Use `nx.random_labeled_tree` instead.\n"
#      60         "See: https://networkx.org/documentation/latest/release/release_3.4.html"
#      61     )
# ---> 62 raise AttributeError(f"module 'networkx' has no attribute '{name}'")
#
# AttributeError: module 'networkx' has no attribute 'info'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(0)

print("NumPy version:", np.__version__)
# Out:
# NumPy version: 2.4.1

# %%
# main reference used: https://www.youtube.com/watch?v=w8yWXqWQYmU

# %%
X = np.random.randn(4, 3)   # 4 samples, 3 features
W = np.random.randn(3, 2)   # 3 inputs → 2 neurons
b = np.random.randn(4, 2)
print("b is: ", b)
Z = X @ W + b
print(X)
print(Z)

print("X shape:", X.shape)
print("W shape:", W.shape)
print("b shape:", b.shape)
print("Z shape:", Z.shape)
# Out:
# b is:  [[ 1.21114529  0.68981816]
#  [ 1.30184623 -0.62808756]
#  [-0.48102712  2.3039167 ]
#  [-1.06001582 -0.1359497 ]]
# [[ 0.09740017  0.39904635 -2.77259276]
#  [ 1.95591231  0.39009332 -0.65240858]
#  [-0.39095338  0.49374178 -0.11610394]
#  [-2.03068447  2.06449286 -0.11054066]]
# [[ 0.23551993  3.63473871]
#  [ 3.49933008 -1.18804335]
#  [-0.19198271  2.8372138 ]
#  [-0.02712724  1.97608267]]
# X shape: (4, 3)
# W shape: (3, 2)
# b shape: (4, 2)
# Z shape: (4, 2)

# %%
A = np.maximum(0, Z)

print(A)
# Out:
# [[0.         0.66076189]
#  [2.15218233 1.33514309]
#  [1.26722461 1.71946404]
#  [1.43169746 0.        ]]

# %%
def load_mnist_images(path):
    with open(path, 'rb') as f:
        data = np.frombuffer(f.read(), dtype=np.uint8, offset=16)
    return data.reshape(-1, 28*28)

def load_mnist_labels(path):
    with open(path, 'rb') as f:
        return np.frombuffer(f.read(), dtype=np.uint8, offset=8)

# Load data
X_train = load_mnist_images("./data/mnist/train-images.idx3-ubyte")
y_train = load_mnist_labels("./data/mnist/train-labels.idx1-ubyte")

X_test = load_mnist_images("./data/mnist/t10k-images.idx3-ubyte")
y_test = load_mnist_labels("./data/mnist/t10k-labels.idx1-ubyte")

# Normalize
X_train = X_train.astype(np.float32) / 255.0
X_test  = X_test.astype(np.float32) / 255.0

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (60000, 784) (60000,)
# (10000, 784) (10000,)

# %%
idx = 7
plt.imshow(X_train[idx].reshape(28, 28), cmap="grey")
plt.title(f"Label: {y_train[idx]}")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(27.5), np.float64(27.5), np.float64(-0.5))

# %%
# Combine labels + pixels like the CSV format
test_data = np.hstack([
    y_test.reshape(-1, 1),   # first column = label
    X_test                  # remaining 784 columns = pixels
])

df = pd.DataFrame(test_data)

# Convert back to NumPy (like in the video)
data_dev = df.to_numpy()

# Split again (exact same pattern as tutorial)
y = data_dev[:, 0].astype(int)
X = data_dev[:, 1:]

#print(X.shape, y.shape)
print("Data Test (numpy array check)):",data_dev.shape)
print("Labels:", data_dev[7,0])
# Out:
# Data (numpy array check)): (10000, 785)
# Labels: 9.0

# %%
m, n = data_dev.shape
np.random.shuffle(data_dev)
data_dev = data_dev[:].T
data_dev.shape
# Out:
# (785, 10000)
